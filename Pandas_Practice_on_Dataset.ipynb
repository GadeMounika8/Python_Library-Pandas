# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv").dropna()

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.shape
# Out:
# (147, 25)

# %% [markdown]
# # To get first  five Rows:

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %% [markdown]
# # To get last five Rows:

# %%
df.tail()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2667        10120               43       76.0               14  3268.00
# 2673        10223               26       67.2               15  1747.20
# 2685        10361               44      100.0               10  5001.92
# 2764        10361               35      100.0               11  4277.35
# 2791        10361               23       95.2               12  2189.60
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2667   4/29/2003 0:00  Shipped       2         4     2003  ...
# 2673   2/20/2004 0:00  Shipped       1         2     2004  ...
# 2685  12/17/2004 0:00  Shipped       4        12     2004  ...
# 2764  12/17/2004 0:00  Shipped       4        12     2004  ...
# 2791  12/17/2004 0:00  Shipped       4        12     2004  ...
#
#                                  ADDRESSLINE1  ADDRESSLINE2       CITY  \
# 2667                        636 St Kilda Road       Level 3  Melbourne
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # To get a specific column from a  DataFrame (or) To select a Pandas Series in a DataFrame:

# %%
df.CITY
# Out:
# 10         Melbourne
# 21         Chatswood
# 40         Chatswood
# 47         Melbourne
# 51      North Sydney
#             ...
# 2667       Melbourne
# 2673       Melbourne
# 2685       Chatswood
# 2764       Chatswood
# 2791       Chatswood
# Name: CITY, Length: 147, dtype: object

# %% [markdown]
#          OR

# %%
df['CITY']
# Out:
# 10         Melbourne
# 21         Chatswood
# 40         Chatswood
# 47         Melbourne
# 51      North Sydney
#             ...
# 2667       Melbourne
# 2673       Melbourne
# 2685       Chatswood
# 2764       Chatswood
# 2791       Chatswood
# Name: CITY, Length: 147, dtype: object

# %%
df.STATE
# Out:
# 10      Victoria
# 21           NSW
# 40           NSW
# 47      Victoria
# 51           NSW
#           ...
# 2667    Victoria
# 2673    Victoria
# 2685         NSW
# 2764         NSW
# 2791         NSW
# Name: STATE, Length: 147, dtype: object

# %% [markdown]
#      OR

# %%
df['STATE']
# Out:
# 10      Victoria
# 21           NSW
# 40           NSW
# 47      Victoria
# 51           NSW
#           ...
# 2667    Victoria
# 2673    Victoria
# 2685         NSW
# 2764         NSW
# 2791         NSW
# Name: STATE, Length: 147, dtype: object

# %%
df.COUNTRY
# Out:
# 10      Australia
# 21      Australia
# 40      Australia
# 47      Australia
# 51      Australia
#           ...
# 2667    Australia
# 2673    Australia
# 2685    Australia
# 2764    Australia
# 2791    Australia
# Name: COUNTRY, Length: 147, dtype: object

# %% [markdown]
#      OR

# %%
df['COUNTRY']
# Out:
# 40      Australia
# 47      Australia
# 51      Australia
# 55      Australia
# 64      Australia
#           ...
# 2667    Australia
# 2673    Australia
# 2685    Australia
# 2764    Australia
# 2791    Australia
# Name: COUNTRY, Length: 145, dtype: object

# %%
df['COUNTRY'].value_counts()
# Out:
# Australia    145
# Name: COUNTRY, dtype: int64

# %%
type(df['COUNTRY'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # To combine two columns:

# %%
df.CITY + ' ' + df.COUNTRY
# Out:
# 10         Melbourne Australia
# 21         Chatswood Australia
# 40         Chatswood Australia
# 47         Melbourne Australia
# 51      North Sydney Australia
#                  ...
# 2667       Melbourne Australia
# 2673       Melbourne Australia
# 2685       Chatswood Australia
# 2764       Chatswood Australia
# 2791       Chatswood Australia
# Length: 147, dtype: object

# %% [markdown]
# # To create a new column after combining two columns of a DataFrame (or) To Create new Pandas Series in a DataFrame:

# %%
df.COUNTRY_CITY = df.CITY + ', ' + df.COUNTRY
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_24224\2863393717.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.COUNTRY_CITY = df.CITY + ', ' + df.COUNTRY

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
#            OR

# %% [markdown]
# Note: It is better to use bracket notation rather than using dot notation to Create new Pandas Series in a DataFrame.

# %%
df['COUNTRY_CITY'] = df.CITY + ' ' + df.COUNTRY

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df['COUNTRY_CITY'] = df.CITY + ', ' + df.COUNTRY

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %% [markdown]
# # To Remove a column from a DataFrame:

# %%
df.drop('COUNTRY_CITY', axis = 1)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...      Level 3
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...      Level 6
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...      Level 6
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...      Level 3
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...     Level 15
#
#             CITY     STATE POSTALCODE    COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
df.drop('COUNTRY_CITY', axis = 1, inplace = True)

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %% [markdown]
# # To Remove  Multiple Columns from a DataFrame:

# %%
df.drop(['CONTACTFIRSTNAME','CONTACT_LAST_NAME'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24224\2516970084.py in <module>
# ----> 1 df.drop(['CONTACTFIRSTNAME','CONTACT_LAST_NAME'], axis = 1)
#
# C:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %% [markdown]
# # To Remove the Rows from a DataFrame:

# %%
df.drop([10, 21], axis = 0, inplace =True)

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
# 55        10120               29      96.34                3  2793.86
# 64        10223               47     100.00                4  5422.39
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
# 55    4/29/2003 0:00  Shipped       2         4     2003  ...
# 64    2/20/2004 0:00  Shipped       1         2     2004  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 40  Monitor Money Building, 815 Pacific Hwy       Level 6     Chatswood
# ...

# %%
df.shape
# Out:
# (145, 25)

# %% [markdown]
# # To Sort a Columns (or) Variables (or) Pandas Series in an Ascending Order:

# %%
df.POSTALCODE.sort_values()
# Out:
# 1270    2060
# 859     2060
# 2127    2060
# 499     2060
# 1020    2060
#         ...
# 646     3004
# 620     3004
# 521     3004
# 2104    3004
# 1990    3004
# Name: POSTALCODE, Length: 145, dtype: object

# %% [markdown]
#          OR

# %%
df['POSTALCODE'].sort_values()
# Out:
# 1270    2060
# 859     2060
# 2127    2060
# 499     2060
# 1020    2060
#         ...
# 646     3004
# 620     3004
# 521     3004
# 2104    3004
# 1990    3004
# Name: POSTALCODE, Length: 145, dtype: object

# %% [markdown]
#                 OR

# %%
df['POSTALCODE'].sort_values(ascending = True)
# Out:
# 1270    2060
# 859     2060
# 2127    2060
# 499     2060
# 1020    2060
#         ...
# 646     3004
# 620     3004
# 521     3004
# 2104    3004
# 1990    3004
# Name: POSTALCODE, Length: 145, dtype: object

# %%
type(df['POSTALCODE'].sort_values())
# Out:
# pandas.core.series.Series

# %%
df.CITY.sort_values()
# Out:
# 40         Chatswood
# 1563       Chatswood
# 1515       Chatswood
# 1437       Chatswood
# 1414       Chatswood
#             ...
# 1417    North Sydney
# 451     North Sydney
# 1395    North Sydney
# 235     North Sydney
# 1561    North Sydney
# Name: CITY, Length: 145, dtype: object

# %%
df.COUNTRY.sort_values()
# Out:
# 40      Australia
# 1565    Australia
# 1574    Australia
# 1639    Australia
# 1673    Australia
#           ...
# 859     Australia
# 884     Australia
# 895     Australia
# 1270    Australia
# 2791    Australia
# Name: COUNTRY, Length: 145, dtype: object

# %%
df['YEAR_ID'].sort_values()
# Out:
# 1374    2003
# 1117    2003
# 2304    2003
# 530     2003
# 1673    2003
#         ...
# 724     2005
# 701     2005
# 599     2005
# 525     2005
# 1288    2005
# Name: YEAR_ID, Length: 145, dtype: int64

# %% [markdown]
# # To Sort a Columns (or) Variables (or) Pandas Series in an descending Order:

# %%
df.ORDERNUMBER.sort_values(ascending = False)
# Out:
# 1288    10420
# 1414    10420
# 1715    10420
# 1791    10420
# 1867    10420
#         ...
# 1517    10120
# 1565    10120
# 2353    10120
# 2099    10120
# 805     10120
# Name: ORDERNUMBER, Length: 145, dtype: int64

# %%
df['YEAR_ID'].sort_values(ascending = False)
# Out:
# 1288    2005
# 2045    2005
# 2299    2005
# 1561    2005
# 1563    2005
#         ...
# 782     2003
# 1168    2003
# 629     2003
# 530     2003
# 1923    2003
# Name: YEAR_ID, Length: 145, dtype: int64

# %% [markdown]
# # To Sort a DataFrame By a Pandas Series:

# %%
df.sort_values('QUANTITYORDERED')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2045        10420               15      43.49                3   652.35
# 2503        10361               20      60.54                4  1210.80
# 2309        10223               20      66.04               12  1320.80
# 911         10139               20      71.20                3  1424.00
# 964         10139               20      90.06                2  1801.20
# ...           ...              ...        ...              ...      ...
# 620         10342               55      65.45                1  3599.75
# 1160        10342               55     100.00                7  6548.30
# 1791        10420               55      96.30                8  5296.50
# 1437        10420               60      64.67               11  3880.20
# 1288        10420               66      92.95                6  6134.70
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
#            OR

# %%
df.sort_values('QUANTITYORDERED', ascending = True)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2045        10420               15      43.49                3   652.35
# 2503        10361               20      60.54                4  1210.80
# 2309        10223               20      66.04               12  1320.80
# 911         10139               20      71.20                3  1424.00
# 964         10139               20      90.06                2  1801.20
# ...           ...              ...        ...              ...      ...
# 620         10342               55      65.45                1  3599.75
# 1160        10342               55     100.00                7  6548.30
# 1791        10420               55      96.30                8  5296.50
# 1437        10420               60      64.67               11  3880.20
# 1288        10420               66      92.95                6  6134.70
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.sort_values('QUANTITYORDERED', ascending = False)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 1288        10420               66      92.95                6  6134.70
# 1437        10420               60      64.67               11  3880.20
# 1791        10420               55      96.30                8  5296.50
# 620         10342               55      65.45                1  3599.75
# 1160        10342               55     100.00                7  6548.30
# ...           ...              ...        ...              ...      ...
# 911         10139               20      71.20                3  1424.00
# 1365        10370               20     100.00                2  2730.00
# 2503        10361               20      60.54                4  1210.80
# 964         10139               20      90.06                2  1801.20
# 2045        10420               15      43.49                3   652.35
#
#             ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
# 55        10120               29      96.34                3  2793.86
# 64        10223               47     100.00                4  5422.39
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
# 55    4/29/2003 0:00  Shipped       2         4     2003  ...
# 64    2/20/2004 0:00  Shipped       1         2     2004  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 40  Monitor Money Building, 815 Pacific Hwy       Level 6     Chatswood
# ...

# %% [markdown]
# # To Sort Multiple Columns in a DataFrame:

# %%
df.sort_values(['CONTACTFIRSTNAME', 'CONTACTLASTNAME'])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 40          10270               21     100.00                9  4905.39
# 75          10361               26      51.15                8  1329.90
# 147         10270               32     100.00                2  4302.08
# 226         10270               28     100.00                6  4094.72
# 434         10270               43      96.84                8  4164.12
# ...           ...              ...        ...              ...      ...
# 2562        10120               24     100.00               15  2584.80
# 2642        10120               24     100.00                7  3417.12
# 2648        10223               29     100.00                8  3199.86
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
# 55        10120               29      96.34                3  2793.86
# 64        10223               47     100.00                4  5422.39
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
# 55    4/29/2003 0:00  Shipped       2         4     2003  ...
# 64    2/20/2004 0:00  Shipped       1         2     2004  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 40  Monitor Money Building, 815 Pacific Hwy       Level 6     Chatswood
# ...

# %% [markdown]
# Old Version of Sort() Methods:

# %%
df.QUANTITYORDERED.order()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24224\1188454595.py in <module>
# ----> 1 df.QUANTITYORDERED.order()
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'order'

# %%
df.sort('QUANTITYORDERED')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24224\2360699774.py in <module>
# ----> 1 df.sort('QUANTITYORDERED')
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %% [markdown]
# # To extract specific rows of pandas DataFrame By Column Value:

# %%
x = []
for i in df.SALES:
    if i > 5000:
        x.append(True)
    else:
        x.append(False)

# %%
x
# Out:
# [False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
# ...

# %%
len(x)
# Out:
# 145

# %%
x[0:10]
# Out:
# [False, False, False, False, True, False, True, True, False, False]

# %%
y = pd.Series(x)
y.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df[x]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 64          10223               47     100.00                4  5422.39
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# 166         10169               30     100.00                2  5019.90
# 235         10370               49     100.00                8  8470.14
# 468         10342               40     100.00                2  6454.40
# 499         10391               35     100.00                2  5548.90
# 530         10148               47     100.00                9  5848.68
# 599         10420               37     100.00                5  5283.60
# 774         10347               50     100.00                8  6834.50
# 832         10125               34     100.00                2  6483.46
# 833         10139               41     100.00                8  7956.46
# ...

# %% [markdown]
#                  or

# %%
y = df.SALES > 5000
y.head()
# Out:
# 40    False
# 47    False
# 51    False
# 55    False
# 64     True
# Name: SALES, dtype: bool

# %%
df[y]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 64          10223               47     100.00                4  5422.39
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# 166         10169               30     100.00                2  5019.90
# 235         10370               49     100.00                8  8470.14
# 468         10342               40     100.00                2  6454.40
# 499         10391               35     100.00                2  5548.90
# 530         10148               47     100.00                9  5848.68
# 599         10420               37     100.00                5  5283.60
# 774         10347               50     100.00                8  6834.50
# 832         10125               34     100.00                2  6483.46
# 833         10139               41     100.00                8  7956.46
# ...

# %% [markdown]
#         or

# %%
df[df.SALES > 5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 64          10223               47     100.00                4  5422.39
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# 166         10169               30     100.00                2  5019.90
# 235         10370               49     100.00                8  8470.14
# 468         10342               40     100.00                2  6454.40
# 499         10391               35     100.00                2  5548.90
# 530         10148               47     100.00                9  5848.68
# 599         10420               37     100.00                5  5283.60
# 774         10347               50     100.00                8  6834.50
# 832         10125               34     100.00                2  6483.46
# 833         10139               41     100.00                8  7956.46
# ...

# %%
df[df.SALES > 5000].DEALSIZE
# Out:
# 64      Medium
# 81       Large
# 90       Large
# 166     Medium
# 235      Large
# 468     Medium
# 499     Medium
# 530     Medium
# 599     Medium
# 774     Medium
# 832     Medium
# 833      Large
# 884     Medium
# 1020    Medium
# 1053    Medium
# 1160    Medium
# 1288    Medium
# 1329    Medium
# 1336    Medium
# 1388    Medium
# 1561     Large
# 1791    Medium
# 1990    Medium
# 2685    Medium
# Name: DEALSIZE, dtype: object

# %% [markdown]
#              OR

# %%
df[df.SALES > 5000]['DEALSIZE']
# Out:
# 64      Medium
# 81       Large
# 90       Large
# 166     Medium
# 235      Large
# 468     Medium
# 499     Medium
# 530     Medium
# 599     Medium
# 774     Medium
# 832     Medium
# 833      Large
# 884     Medium
# 1020    Medium
# 1053    Medium
# 1160    Medium
# 1288    Medium
# 1329    Medium
# 1336    Medium
# 1388    Medium
# 1561     Large
# 1791    Medium
# 1990    Medium
# 2685    Medium
# Name: DEALSIZE, dtype: object

# %%
df.loc('SALES' > 5000,'DEALSIZE')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24224\3837755055.py in <module>
# ----> 1 df.loc('SALES' > 5000,'DEALSIZE')
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# # How do We Select or extract Multiple Columns by filtering Rows with a condition:

# %%
(df.SALES > 5000) & (df.DEALSIZE =='Large')
# Out:
# 40      False
# 47      False
# 51      False
# 55      False
# 64      False
#         ...
# 2667    False
# 2673    False
# 2685    False
# 2764    False
# 2791    False
# Length: 145, dtype: bool

# %%
df[(df.SALES > 5000) & (df.DEALSIZE =='Large')]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 81          10120               46      100.0                2  9264.86
# 90          10223               49      100.0                3  9774.03
# 235         10370               49      100.0                8  8470.14
# 833         10139               41      100.0                8  7956.46
# 1561        10391               33      100.0                8  8344.71
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 81      4/29/2003 0:00  Shipped       2         4     2003  ...
# 90      2/20/2004 0:00  Shipped       1         2     2004  ...
# 235     1/20/2005 0:00  Shipped       1         1     2005  ...
# 833     7/16/2003 0:00  Shipped       3         7     2003  ...
# 1561  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                  ADDRESSLINE1  ADDRESSLINE2          CITY  \
# ...

# %%
df[(df.SALES > 5000) & (df.DEALSIZE =='Large') & (df.ADDRESSLINE2 == 'Level 3')]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 81        10120               46      100.0                2  9264.86
# 90        10223               49      100.0                3  9774.03
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 81  4/29/2003 0:00  Shipped       2         4     2003  ...
# 90  2/20/2004 0:00  Shipped       1         2     2004  ...
#
#          ADDRESSLINE1  ADDRESSLINE2       CITY     STATE POSTALCODE  \
# 81  636 St Kilda Road       Level 3  Melbourne  Victoria       3004
# 90  636 St Kilda Road       Level 3  Melbourne  Victoria       3004
#
#       COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 81  Australia      APAC        Ferguson            Peter    Large
# 90  Australia      APAC        Ferguson            Peter    Large
#
# [2 rows x 25 columns]

# %%
df[(df.SALES > 5000) | (df.DEALSIZE =='Large')]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 64          10223               47     100.00                4  5422.39
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# 166         10169               30     100.00                2  5019.90
# 235         10370               49     100.00                8  8470.14
# 468         10342               40     100.00                2  6454.40
# 499         10391               35     100.00                2  5548.90
# 530         10148               47     100.00                9  5848.68
# 599         10420               37     100.00                5  5283.60
# 774         10347               50     100.00                8  6834.50
# 832         10125               34     100.00                2  6483.46
# 833         10139               41     100.00                8  7956.46
# ...

# %%
df[(df.SALES > 5000) | (df.DEALSIZE =='Large') | (df.ADDRESSLINE2 == 'Level 3')]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 47          10347               30     100.00                1  3944.70
# 55          10120               29      96.34                3  2793.86
# 64          10223               47     100.00                4  5422.39
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# ...           ...              ...        ...              ...      ...
# 2642        10120               24     100.00                7  3417.12
# 2648        10223               29     100.00                8  3199.86
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
#              or

# %%
df.DEALSIZE.value_counts()
# Out:
# Medium    70
# Small     70
# Large      5
# Name: DEALSIZE, dtype: int64

# %%
df[(df.DEALSIZE == 'Large') | (df.DEALSIZE == 'Small')]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 51          10391               24     100.00                4  2416.56
# 55          10120               29      96.34                3  2793.86
# 75          10361               26      51.15                8  1329.90
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# ...           ...              ...        ...              ...      ...
# 2555        10361               24      45.39               14  1089.36
# 2562        10120               24     100.00               15  2584.80
# 2582        10361               26     100.00                9  2754.70
# 2673        10223               26      67.20               15  1747.20
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
#           OR

# %%
df.DEALSIZE.isin(['Large', 'Small'])
# Out:
# 40      False
# 47      False
# 51       True
# 55       True
# 64      False
#         ...
# 2667    False
# 2673     True
# 2685    False
# 2764    False
# 2791     True
# Name: DEALSIZE, Length: 145, dtype: bool

# %%
df[df.DEALSIZE.isin(['Large', 'Small'])]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 51          10391               24     100.00                4  2416.56
# 55          10120               29      96.34                3  2793.86
# 75          10361               26      51.15                8  1329.90
# 81          10120               46     100.00                2  9264.86
# 90          10223               49     100.00                3  9774.03
# ...           ...              ...        ...              ...      ...
# 2555        10361               24      45.39               14  1089.36
# 2562        10120               24     100.00               15  2584.80
# 2582        10361               26     100.00                9  2754.70
# 2673        10223               26      67.20               15  1747.20
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # To know the number of Rows and Columns:

# %%
df.shape
# Out:
# (145, 25)

# %% [markdown]
# # To know all the columns Datatypes:

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# COUNTRY_CITY         object
# dtype: object

# %% [markdown]
# # To show all the columns names:

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE', 'COUNTRY_CITY'],
#       dtype='object')

# %% [markdown]
# # To Rename Single Column name in a DataFrame:

# %%
df.rename(columns = {'ORDERNUMBER':'ORDER_NUMBER'})
# Out:
#       ORDER_NUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10           10223               37     100.00                1  3965.66
# 21           10361               20      72.55               13  1451.00
# 40           10270               21     100.00                9  4905.39
# 47           10347               30     100.00                1  3944.70
# 51           10391               24     100.00                4  2416.56
# ...            ...              ...        ...              ...      ...
# 2667         10120               43      76.00               14  3268.00
# 2673         10223               26      67.20               15  1747.20
# 2685         10361               44     100.00               10  5001.92
# 2764         10361               35     100.00               11  4277.35
# 2791         10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %% [markdown]
# # To Rename Multiple Columns names in a DataFrame:

# %%
df.rename(columns = {'ORDERNUMBER':'ORDER_NUMBER', 'PRICEEACH':'PRICE_EACH', 'CONTACTLASTNAME':'CONTACT_LAST_NAME'})
# Out:
#       ORDER_NUMBER  QUANTITYORDERED  PRICE_EACH  ORDERLINENUMBER    SALES  \
# 10           10223               37      100.00                1  3965.66
# 21           10361               20       72.55               13  1451.00
# 40           10270               21      100.00                9  4905.39
# 47           10347               30      100.00                1  3944.70
# 51           10391               24      100.00                4  2416.56
# ...            ...              ...         ...              ...      ...
# 2667         10120               43       76.00               14  3268.00
# 2673         10223               26       67.20               15  1747.20
# 2685         10361               44      100.00               10  5001.92
# 2764         10361               35      100.00               11  4277.35
# 2791         10361               23       95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
df.rename(columns = {'ORDERNUMBER':'ORDER_NUMBER', 'PRICEEACH':'PRICE_EACH', 'CONTACTLASTNAME':'CONTACT_LAST_NAME'}, inplace = True)

# %%
df.columns
# Out:
# Index(['ORDER_NUMBER', 'QUANTITYORDERED', 'PRICE_EACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACT_LAST_NAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE', 'COUNTRY_CITY'],
#       dtype='object')

# %% [markdown]
# # To Rename All the Column names in a DataFrame:

# %%
df_cols = ['ORDER_NUMBER', 'QUANTITY_ORDERED', 'PRICE_EACH', 'ORDER_LINE_NUMBER',
       'Sales', 'ORDER_DATE', 'STATUS', 'QTR_Id', 'MONTH_Id', 'YEAR_Id',
       'PRODUCT_LINE', 'msrp', 'PRODUCT_CODE', 'CUSTOMER_NAME', 'Phone',
       'ADDRESSLINE_1', 'ADDRESSLINE_2', 'City', 'State', 'POSTAL_CODE',
       'Country', 'Territory', 'CONTACT_LAST_NAME', 'CONTACT_FIRST_NAME',
       'DEAL_SIZE', 'Country_City'],
      
df.columns = df_cols
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24552\2725301576.py in <module>
#       6        'DEAL_SIZE', 'Country_City'],
#       7
# ----> 8 df.columns = df_cols
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# C:\anaconda\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
# ...

# %% [markdown]
# # To know all the information about a DataFrame:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 10 to 2791
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ORDER_NUMBER       147 non-null    int64
#  1   QUANTITYORDERED    147 non-null    int64
#  2   PRICE_EACH         147 non-null    float64
#  3   ORDERLINENUMBER    147 non-null    int64
#  4   SALES              147 non-null    float64
#  5   ORDERDATE          147 non-null    object
#  6   STATUS             147 non-null    object
#  7   QTR_ID             147 non-null    int64
#  8   MONTH_ID           147 non-null    int64
#  9   YEAR_ID            147 non-null    int64
#  10  PRODUCTLINE        147 non-null    object
#  11  MSRP               147 non-null    int64
#  12  PRODUCTCODE        147 non-null    object
#  13  CUSTOMERNAME       147 non-null    object
#  14  PHONE              147 non-null    object
#  15  ADDRESSLINE1       147 non-null    object
# ...

# %% [markdown]
# # To get Discriptive statistics of all the numerical variables from the DataFrame:

# %%
df.describe()
# Out:
#        ORDER_NUMBER  QUANTITYORDERED  PRICE_EACH  ORDERLINENUMBER  \
# count    147.000000       147.000000  147.000000       147.000000
# mean   10268.204082        33.986395   84.138639         6.673469
# std      106.742036         9.740458   19.897255         3.830596
# min    10120.000000        15.000000   26.880000         1.000000
# 25%    10148.000000        26.000000   66.390000         3.000000
# 50%    10270.000000        33.000000   98.050000         6.000000
# 75%    10361.000000        41.000000  100.000000        10.000000
# max    10420.000000        66.000000  100.000000        15.000000
#
#              SALES      QTR_ID    MONTH_ID      YEAR_ID        MSRP
# count   147.000000  147.000000  147.000000   147.000000  147.000000
# mean   3446.003537    2.673469    6.986395  2003.863946  100.632653
# std    1717.988835    1.171367    3.734303     0.746127   40.046562
# min     652.350000    1.000000    1.000000  2003.000000   33.000000
# ...

# %%
df.describe(include = ['object'])
# Out:
#              ORDERDATE   STATUS   PRODUCTLINE PRODUCTCODE  \
# count              147      147           147         147
# unique              13        2             6          76
# top     2/20/2004 0:00  Shipped  Classic Cars    S18_2949
# freq                15      134            46           4
#
#                       CUSTOMERNAME         PHONE       ADDRESSLINE1  \
# count                          147           147                147
# unique                           3             3                  3
# top     Australian Collectors, Co.  03 9520 4555  636 St Kilda Road
# freq                            55            55                 55
#
#        ADDRESSLINE2       CITY STATE POSTALCODE    COUNTRY TERRITORY  \
# count           147        147   147        147        147       147
# unique            3          3     2          3          1         1
# top         Level 3  Melbourne   NSW       3004  Australia      APAC
# ...

# %% [markdown]
# # To get minimum value of sales from a SALES column in a DataFrame:

# %%
df.SALES.min()
# Out:
# 652.35

# %% [markdown]
#       OR

# %%
np.min(df.SALES)
# Out:
# 652.35

# %% [markdown]
# # To get maximum value of sales from a SALES column in a DataFrame:

# %%
df.SALES.max()
# Out:
# 9774.03

# %% [markdown]
#       OR

# %%
np.max(df.SALES)
# Out:
# 9774.03

# %% [markdown]
# # To get Average value of sales from a SALES column in a DataFrame:

# %%
df.SALES.mean()
# Out:
# 3446.0035374149647

# %% [markdown]
#        OR

# %%
np.mean(df.SALES)
# Out:
# 3446.0035374149647

# %% [markdown]
# # To get Mean values of All numeric columns:

# %%
df.mean()
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# ORDERNUMBER        1.026820e+04
# QUANTITYORDERED    3.398639e+01
# PRICEEACH          8.413864e+01
# ORDERLINENUMBER    6.673469e+00
# SALES              3.446004e+03
# QTR_ID             2.673469e+00
# MONTH_ID           6.986395e+00
# YEAR_ID            2.003864e+03
# MSRP               1.006327e+02
# POSTALCODE                  inf
# dtype: float64

# %%
df.mean().shape
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\2795217473.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean().shape
# (10,)

# %% [markdown]
#           or

# %%
df.mean(axis = 0)
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\777590737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 0)
# ORDERNUMBER        1.026820e+04
# QUANTITYORDERED    3.398639e+01
# PRICEEACH          8.413864e+01
# ORDERLINENUMBER    6.673469e+00
# SALES              3.446004e+03
# QTR_ID             2.673469e+00
# MONTH_ID           6.986395e+00
# YEAR_ID            2.003864e+03
# MSRP               1.006327e+02
# POSTALCODE                  inf
# dtype: float64

# %%
df.mean(axis = 0).shape
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\428073375.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 0).shape
# (10,)

# %% [markdown]
#      or

# %%
df.mean(axis = 'index')
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\1007144109.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 'index')
# ORDERNUMBER        1.026820e+04
# QUANTITYORDERED    3.398639e+01
# PRICEEACH          8.413864e+01
# ORDERLINENUMBER    6.673469e+00
# SALES              3.446004e+03
# QTR_ID             2.673469e+00
# MONTH_ID           6.986395e+00
# YEAR_ID            2.003864e+03
# MSRP               1.006327e+02
# POSTALCODE                  inf
# dtype: float64

# %%
df.mean(axis = 'index').shape
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\465507047.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 'index').shape
# (10,)

# %%
df.mean(axis = 1)
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\3216275966.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 1)
# 10      1825.406667
# 21      1559.172222
# 40      1948.154444
# 47      1850.633333
# 51      1684.284444
#            ...
# 2667    1734.444444
# 2673    1573.933333
# 2685    1957.435556
# 2764    1875.372222
# 2791    1638.866667
# Length: 147, dtype: float64

# %%
df.mean(axis = 1).shape
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\57517804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 1).shape
# (147,)

# %% [markdown]
#           or

# %%
df.mean(axis = 'columns')
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\1438213737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 'columns')
# 10      1825.406667
# 21      1559.172222
# 40      1948.154444
# 47      1850.633333
# 51      1684.284444
#            ...
# 2667    1734.444444
# 2673    1573.933333
# 2685    1957.435556
# 2764    1875.372222
# 2791    1638.866667
# Length: 147, dtype: float64

# %%
df.mean(axis = 'columns').shape
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\4062896820.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 'columns').shape
# (147,)

# %% [markdown]
# # To know the median value of SALES Column:

# %%
df.SALES.median()
# Out:
# 3160.74

# %% [markdown]
# # What about reading from csv file only some columns and not all columns?

# %%
import pandas as pd

# %%
df1 =pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv", usecols = ['ORDERNUMBER', 'SALES', 'QUANTITYORDERED', 'CITY', 'STATE', 'COUNTRY', 'DEALSIZE']).dropna()

# %%
df1
# Out:
#       ORDERNUMBER  QUANTITYORDERED    SALES           CITY   STATE COUNTRY  \
# 0           10107               30  2871.00            NYC      NY     USA
# 3           10145               45  3746.70       Pasadena      CA     USA
# 4           10159               49  5205.27  San Francisco      CA     USA
# 5           10168               36  3479.76     Burlingame      CA     USA
# 8           10201               22  2168.54  San Francisco      CA     USA
# ...           ...              ...      ...            ...     ...     ...
# 2809        10248               23  1506.96            NYC      NY     USA
# 2810        10261               29  1472.62       Montreal  Quebec  Canada
# 2812        10283               33  1693.56      Tsawassen      BC  Canada
# 2817        10337               42  4080.72            NYC      NY     USA
# 2822        10414               47  3079.44         Boston      MA     USA
#
#      DEALSIZE
# 0       Small
# 3      Medium
# 4      Medium
# ...

# %% [markdown]
#          or

# %%
df1 =pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv", usecols = [0, 4, 1, 17, 18, 20, 24]).dropna()

# %%
df1
# Out:
#       ORDERNUMBER  QUANTITYORDERED    SALES           CITY   STATE COUNTRY  \
# 0           10107               30  2871.00            NYC      NY     USA
# 3           10145               45  3746.70       Pasadena      CA     USA
# 4           10159               49  5205.27  San Francisco      CA     USA
# 5           10168               36  3479.76     Burlingame      CA     USA
# 8           10201               22  2168.54  San Francisco      CA     USA
# ...           ...              ...      ...            ...     ...     ...
# 2809        10248               23  1506.96            NYC      NY     USA
# 2810        10261               29  1472.62       Montreal  Quebec  Canada
# 2812        10283               33  1693.56      Tsawassen      BC  Canada
# 2817        10337               42  4080.72            NYC      NY     USA
# 2822        10414               47  3079.44         Boston      MA     USA
#
#      DEALSIZE
# 0       Small
# 3      Medium
# 4      Medium
# ...

# %%
df1.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'SALES', 'CITY', 'STATE', 'COUNTRY',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # How to read some (or)  required rows from a DataFrame?

# %%
df2 = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv", nrows = 15)

# %%
df2
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# ...

# %%
df2.head(15)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0         10107               30      95.70                2  2871.00
# 1         10121               34      81.35                5  2765.90
# 2         10134               41      94.74                2  3884.34
# 3         10145               45      83.26                6  3746.70
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
# 11        10237               23     100.00                7  2333.12
# ...

# %% [markdown]
# # How do DataFrames and Series work with regard to selecting individual entries and iteration (for X in userdata:)?

# %%
df2.DEALSIZE.value_counts()
# Out:
# Medium    10
# Small      5
# Name: DEALSIZE, dtype: int64

# %%
df.COUNTRY.value_counts()
# Out:
# USA          1004
# Australia     185
# Canada         70
# Japan          52
# UK             26
# Name: COUNTRY, dtype: int64

# %%
for i in df2.DEALSIZE:
    print(i)
# Out:
# Small
# Small
# Medium
# Medium
# Medium
# Medium
# Small
# Medium
# Small
# Medium
# Medium
# Small
# Medium
# Medium
# Medium

# %%
for index,row in df2.iterrows():
    print(index, row.CITY, row.STATE)
# Out:
# 0 NYC NY
# 1 Reims nan
# 2 Paris nan
# 3 Pasadena CA
# 4 San Francisco CA
# 5 Burlingame CA
# 6 Lille nan
# 7 Bergen nan
# 8 San Francisco CA
# 9 Paris nan
# 10 Melbourne Victoria
# 11 NYC NY
# 12 Newark NJ
# 13 Bridgewater CT
# 14 Nantes nan

# %%
for index,row in df2.iterrows():
    print(index, row.CITY, row.STATE, row.COUNTRY)
# Out:
# 0 NYC NY USA
# 1 Reims nan France
# 2 Paris nan France
# 3 Pasadena CA USA
# 4 San Francisco CA USA
# 5 Burlingame CA USA
# 6 Lille nan France
# 7 Bergen nan Norway
# 8 San Francisco CA USA
# 9 Paris nan France
# 10 Melbourne Victoria Australia
# 11 NYC NY USA
# 12 Newark NJ USA
# 13 Bridgewater CT USA
# 14 Nantes nan France

# %%
for index,row in df2.iterrows():
    print(index, row.CITY,',', row.STATE,',', row.COUNTRY)
# Out:
# 0 NYC , NY , USA
# 1 Reims , nan , France
# 2 Paris , nan , France
# 3 Pasadena , CA , USA
# 4 San Francisco , CA , USA
# 5 Burlingame , CA , USA
# 6 Lille , nan , France
# 7 Bergen , nan , Norway
# 8 San Francisco , CA , USA
# 9 Paris , nan , France
# 10 Melbourne , Victoria , Australia
# 11 NYC , NY , USA
# 12 Newark , NJ , USA
# 13 Bridgewater , CT , USA
# 14 Nantes , nan , France

# %% [markdown]
# # What is the better approach to drop non_numeric columns in a DataFrame?

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv").dropna()

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
import numpy as np

# %%
df.select_dtypes(include = [np.number]).dtypes
# Out:
# ORDERNUMBER          int64
# QUANTITYORDERED      int64
# PRICEEACH          float64
# ORDERLINENUMBER      int64
# SALES              float64
# QTR_ID               int64
# MONTH_ID             int64
# YEAR_ID              int64
# MSRP                 int64
# dtype: object

# %%
df.select_dtypes(include = [np.object]).dtypes
# Out:
# C:\Users\mouni\AppData\Local\Temp\ipykernel_8496\2571061375.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df.select_dtypes(include = [np.object]).dtypes
# ORDERDATE           object
# STATUS              object
# PRODUCTLINE         object
# PRODUCTCODE         object
# CUSTOMERNAME        object
# PHONE               object
# ADDRESSLINE1        object
# ADDRESSLINE2        object
# CITY                object
# STATE               object
# POSTALCODE          object
# COUNTRY             object
# TERRITORY           object
# CONTACTLASTNAME     object
# CONTACTFIRSTNAME    object
# DEALSIZE            object
# dtype: object

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count    147.000000       147.000000  147.000000       147.000000
# mean   10268.204082        33.986395   84.138639         6.673469
# std      106.742036         9.740458   19.897255         3.830596
# min    10120.000000        15.000000   26.880000         1.000000
# 25%    10148.000000        26.000000   66.390000         3.000000
# 50%    10270.000000        33.000000   98.050000         6.000000
# 75%    10361.000000        41.000000  100.000000        10.000000
# max    10420.000000        66.000000  100.000000        15.000000
#
#              SALES      QTR_ID    MONTH_ID      YEAR_ID        MSRP
# count   147.000000  147.000000  147.000000   147.000000  147.000000
# mean   3446.003537    2.673469    6.986395  2003.863946  100.632653
# std    1717.988835    1.171367    3.734303     0.746127   40.046562
# min     652.350000    1.000000    1.000000  2003.000000   33.000000
# ...

# %% [markdown]
#                   or

# %%
df.describe(include = ['number'])
# Out:
#         ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count    147.000000       147.000000  147.000000       147.000000
# mean   10268.204082        33.986395   84.138639         6.673469
# std      106.742036         9.740458   19.897255         3.830596
# min    10120.000000        15.000000   26.880000         1.000000
# 25%    10148.000000        26.000000   66.390000         3.000000
# 50%    10270.000000        33.000000   98.050000         6.000000
# 75%    10361.000000        41.000000  100.000000        10.000000
# max    10420.000000        66.000000  100.000000        15.000000
#
#              SALES      QTR_ID    MONTH_ID      YEAR_ID        MSRP
# count   147.000000  147.000000  147.000000   147.000000  147.000000
# mean   3446.003537    2.673469    6.986395  2003.863946  100.632653
# std    1717.988835    1.171367    3.734303     0.746127   40.046562
# min     652.350000    1.000000    1.000000  2003.000000   33.000000
# ...

# %%
df.describe(include = ['object'])
# Out:
#              ORDERDATE   STATUS   PRODUCTLINE PRODUCTCODE  \
# count              147      147           147         147
# unique              13        2             6          76
# top     2/20/2004 0:00  Shipped  Classic Cars    S18_2949
# freq                15      134            46           4
#
#                       CUSTOMERNAME         PHONE       ADDRESSLINE1  \
# count                          147           147                147
# unique                           3             3                  3
# top     Australian Collectors, Co.  03 9520 4555  636 St Kilda Road
# freq                            55            55                 55
#
#        ADDRESSLINE2       CITY STATE POSTALCODE    COUNTRY TERRITORY  \
# count           147        147   147        147        147       147
# unique            3          3     2          3          1         1
# top         Level 3  Melbourne   NSW       3004  Australia      APAC
# ...

# %%
df.describe(include = ['number','object'])
# Out:
#          ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count     147.000000       147.000000  147.000000       147.000000
# unique           NaN              NaN         NaN              NaN
# top              NaN              NaN         NaN              NaN
# freq             NaN              NaN         NaN              NaN
# mean    10268.204082        33.986395   84.138639         6.673469
# std       106.742036         9.740458   19.897255         3.830596
# min     10120.000000        15.000000   26.880000         1.000000
# 25%     10148.000000        26.000000   66.390000         3.000000
# 50%     10270.000000        33.000000   98.050000         6.000000
# 75%     10361.000000        41.000000  100.000000        10.000000
# max     10420.000000        66.000000  100.000000        15.000000
#
#               SALES       ORDERDATE   STATUS      QTR_ID    MONTH_ID  \
# count    147.000000             147      147  147.000000  147.000000
# ...

# %%
df.describe(include = 'all')
# Out:
#          ORDERNUMBER  QUANTITYORDERED   PRICEEACH  ORDERLINENUMBER  \
# count     147.000000       147.000000  147.000000       147.000000
# unique           NaN              NaN         NaN              NaN
# top              NaN              NaN         NaN              NaN
# freq             NaN              NaN         NaN              NaN
# mean    10268.204082        33.986395   84.138639         6.673469
# std       106.742036         9.740458   19.897255         3.830596
# min     10120.000000        15.000000   26.880000         1.000000
# 25%     10148.000000        26.000000   66.390000         3.000000
# 50%     10270.000000        33.000000   98.050000         6.000000
# 75%     10361.000000        41.000000  100.000000        10.000000
# max     10420.000000        66.000000  100.000000        15.000000
#
#               SALES       ORDERDATE   STATUS      QTR_ID    MONTH_ID  \
# count    147.000000             147      147  147.000000  147.000000
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv").dropna()

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %% [markdown]
# # The Usage of axis Parameter:

# %% [markdown]
# # To Drop a Column with axis Parameter:

# %%
df.drop('QTR_ID', axis = 1).head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  MONTH_ID  YEAR_ID   PRODUCTLINE  ...  \
# 10    2/20/2004 0:00  Shipped         2     2004   Motorcycles  ...
# 21   12/17/2004 0:00  Shipped        12     2004   Motorcycles  ...
# 40    7/19/2004 0:00  Shipped         7     2004  Classic Cars  ...
# 47   11/29/2004 0:00  Shipped        11     2004  Classic Cars  ...
# 51  03-09-2005 00:00  Shipped         3     2005  Classic Cars  ...
#
#                                ADDRESSLINE1 ADDRESSLINE2          CITY  \
# ...

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 51          10391               24     100.00                4  2416.56
# ...           ...              ...        ...              ...      ...
# 2667        10120               43      76.00               14  3268.00
# 2673        10223               26      67.20               15  1747.20
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
# 2791        10361               23      95.20               12  2189.60
#
#              ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# # To Drop a Row with axis Parameter:

# %%
df.drop(40, axis = 0).head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
# 55        10120               29      96.34                3  2793.86
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
# 55    4/29/2003 0:00  Shipped       2         4     2003  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %% [markdown]
# # String Functions:

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv").dropna()

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %%
df.DEALSIZE.str.upper()
# Out:
# 10      MEDIUM
# 21       SMALL
# 40      MEDIUM
# 47      MEDIUM
# 51       SMALL
#          ...
# 2667    MEDIUM
# 2673     SMALL
# 2685    MEDIUM
# 2764    MEDIUM
# 2791     SMALL
# Name: DEALSIZE, Length: 147, dtype: object

# %%
df.DEALSIZE.str.contains('Medium')
# Out:
# 10       True
# 21      False
# 40       True
# 47       True
# 51      False
#         ...
# 2667     True
# 2673    False
# 2685     True
# 2764     True
# 2791    False
# Name: DEALSIZE, Length: 147, dtype: bool

# %%
df[df.DEALSIZE.str.contains('Medium')]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10          10223               37     100.00                1  3965.66
# 40          10270               21     100.00                9  4905.39
# 47          10347               30     100.00                1  3944.70
# 64          10223               47     100.00                4  5422.39
# 147         10270               32     100.00                2  4302.08
# ...           ...              ...        ...              ...      ...
# 2648        10223               29     100.00                8  3199.86
# 2660        10361               44      72.42                5  3186.48
# 2667        10120               43      76.00               14  3268.00
# 2685        10361               44     100.00               10  5001.92
# 2764        10361               35     100.00               11  4277.35
#
#             ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.ORDERDATE.str.replace('/','-')
# Out:
# 10        2-20-2004 0:00
# 21       12-17-2004 0:00
# 40        7-19-2004 0:00
# 47       11-29-2004 0:00
# 51      03-09-2005 00:00
#               ...
# 2667      4-29-2003 0:00
# 2673      2-20-2004 0:00
# 2685     12-17-2004 0:00
# 2764     12-17-2004 0:00
# 2791     12-17-2004 0:00
# Name: ORDERDATE, Length: 147, dtype: object

# %% [markdown]
# # How would I change the data type of a Variable (or) Column (or) Pandas Series?

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv").dropna()

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df['POSTALCODE'] = df.POSTALCODE.astype(int)

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE            int32
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %% [markdown]
# # How to change (or) give the data types of columns in a DataFrame while reading a file?

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv", dtype = {'POSTALCODE':object}).dropna()

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %% [markdown]
# --> this Data type conversion is useful in ML.

# %%
df.DEALSIZE.str.contains('Large').head(10)
# Out:
# 10    False
# 21    False
# 40    False
# 47    False
# 51    False
# 55    False
# 64    False
# 75    False
# 81     True
# 90     True
# Name: DEALSIZE, dtype: bool

# %%
df.DEALSIZE.str.contains('Large').astype(int).head(10)
# Out:
# 10    0
# 21    0
# 40    0
# 47    0
# 51    0
# 55    0
# 64    0
# 75    0
# 81    1
# 90    1
# Name: DEALSIZE, dtype: int32

# %% [markdown]
# # How to use a groupby in Pandas?

# %%
df.CITY.value_counts()
# Out:
# Melbourne       55
# Chatswood       46
# North Sydney    46
# Name: CITY, dtype: int64

# %%
df.STATE.value_counts()
# Out:
# NSW         92
# Victoria    55
# Name: STATE, dtype: int64

# %%
df.SALES.mean()
# Out:
# 3446.0035374149647

# %%
df.groupby('ADDRESSLINE2').SALES.mean()
# Out:
# ADDRESSLINE2
# Level 15    3347.741957
# Level 3     3654.462000
# Level 6     3295.021304
# Name: SALES, dtype: float64

# %%
df[df.ADDRESSLINE2 == 'Level 6']
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 21          10361               20      72.55               13  1451.00
# 40          10270               21     100.00                9  4905.39
# 75          10361               26      51.15                8  1329.90
# 147         10270               32     100.00                2  4302.08
# 226         10270               28     100.00                6  4094.72
# 434         10270               43      96.84                8  4164.12
# 478         10139               31     100.00                7  3184.94
# 504         10139               49      43.13                6  2113.37
# 599         10420               37     100.00                5  5283.60
# 701         10420               36      63.57                4  2288.52
# 752         10420               45     100.00                2  4977.00
# 833         10139               41     100.00                8  7956.46
# ...

# %%
df[df.ADDRESSLINE2 == 'Level 6'].SALES.mean()
# Out:
# 3295.021304347827

# %%
df[df.CITY == 'Chatswood'].SALES.mean()
# Out:
# 3295.021304347827

# %%
df.groupby('ADDRESSLINE2').SALES.max()
# Out:
# ADDRESSLINE2
# Level 15    8470.14
# Level 3     9774.03
# Level 6     7956.46
# Name: SALES, dtype: float64

# %%
df.groupby('ADDRESSLINE2').SALES.min()
# Out:
# ADDRESSLINE2
# Level 15    1035.58
# Level 3     1237.95
# Level 6      652.35
# Name: SALES, dtype: float64

# %%
df.groupby('ADDRESSLINE2').SALES.agg(['min', 'max', 'mean', 'count'])
# Out:
#                   min      max         mean  count
# ADDRESSLINE2
# Level 15      1035.58  8470.14  3347.741957     46
# Level 3       1237.95  9774.03  3654.462000     55
# Level 6        652.35  7956.46  3295.021304     46

# %%
df.groupby('SALES').mean()
# Out:
#          ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  QTR_ID  \
# SALES
# 652.35       10420.0             15.0      43.49              3.0     2.0
# 1035.58      10169.0             26.0      39.83              9.0     4.0
# 1089.36      10361.0             24.0      45.39             14.0     4.0
# 1209.60      10420.0             45.0      26.88              1.0     2.0
# 1210.80      10361.0             20.0      60.54              4.0     4.0
# ...              ...              ...        ...              ...     ...
# 7956.46      10139.0             41.0     100.00              8.0     3.0
# 8344.71      10391.0             33.0     100.00              8.0     1.0
# 8470.14      10370.0             49.0     100.00              8.0     1.0
# 9264.86      10120.0             46.0     100.00              2.0     2.0
# 9774.03      10223.0             49.0     100.00              3.0     1.0
#
#          MONTH_ID  YEAR_ID   MSRP
# SALES
# ...

# %%
# %matplotlib inline

# %%
df.groupby('CITY').mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='CITY'>

# %%
df.groupby('STATE').mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='STATE'>

# %%
df.groupby('COUNTRY').mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='COUNTRY'>

# %% [markdown]
# # How would I explore a Pandas Series?

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mouni\Downloads\sales.csv").dropna()

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#            ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10    2/20/2004 0:00  Shipped       1         2     2004  ...
# 21   12/17/2004 0:00  Shipped       4        12     2004  ...
# 40    7/19/2004 0:00  Shipped       3         7     2004  ...
# 47   11/29/2004 0:00  Shipped       4        11     2004  ...
# 51  03-09-2005 00:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %%
df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# MSRP                  int64
# PRODUCTCODE          object
# CUSTOMERNAME         object
# PHONE                object
# ADDRESSLINE1         object
# ADDRESSLINE2         object
# CITY                 object
# STATE                object
# POSTALCODE           object
# COUNTRY              object
# TERRITORY            object
# CONTACTLASTNAME      object
# CONTACTFIRSTNAME     object
# DEALSIZE             object
# dtype: object

# %%
df.CITY.describe()
# Out:
# count           147
# unique            3
# top       Melbourne
# freq             55
# Name: CITY, dtype: object

# %%
df.COUNTRY.describe()
# Out:
# count           147
# unique            1
# top       Australia
# freq            147
# Name: COUNTRY, dtype: object

# %%
df.CITY.value_counts()
# Out:
# Melbourne       55
# Chatswood       46
# North Sydney    46
# Name: CITY, dtype: int64

# %%
df.CITY.value_counts(normalize =True)
# Out:
# Melbourne       0.374150
# Chatswood       0.312925
# North Sydney    0.312925
# Name: CITY, dtype: float64

# %%
type(df.CITY.value_counts())
# Out:
# pandas.core.series.Series

# %%
df.YEAR_ID.value_counts().head()
# Out:
# 2004    63
# 2003    52
# 2005    32
# Name: YEAR_ID, dtype: int64

# %%
df.CITY.unique()
# Out:
# array(['Melbourne', 'Chatswood', 'North Sydney'], dtype=object)

# %%
df.CITY.nunique()
# Out:
# 3

# %%
df.STATE.unique()
# Out:
# array(['Victoria', 'NSW'], dtype=object)

# %%
df.STATE.nunique()
# Out:
# 2

# %%
df.COUNTRY.unique()
# Out:
# array(['Australia'], dtype=object)

# %%
df.COUNTRY.nunique()
# Out:
# 1

# %%
pd.crosstab(df.CITY, df.ADDRESSLINE2)
# Out:
# ADDRESSLINE2  Level 15  Level 3  Level 6
# CITY
# Chatswood            0        0       46
# Melbourne            0       55        0
# North Sydney        46        0        0

# %%
pd.crosstab(df.DEALSIZE, df.SALES)
# Out:
# SALES     652.35   1035.58  1089.36  1209.60  1210.80  1237.95  1320.80  \
# DEALSIZE
# Large           0        0        0        0        0        0        0
# Medium          0        0        0        0        0        0        0
# Small           1        1        1        1        1        1        1
#
# SALES     1329.90  1330.35  1424.00  ...  6276.46  6454.40  6483.46  6548.30  \
# DEALSIZE                             ...
# Large           0        0        0  ...        0        0        0        0
# Medium          0        0        0  ...        1        1        1        1
# Small           1        1        1  ...        0        0        0        0
#
# SALES     6834.50  7956.46  8344.71  8470.14  9264.86  9774.03
# DEALSIZE
# Large           0        1        1        1        1        1
# Medium          1        0        0        0        0        0
# Small           0        0        0        0        0        0
#
# [3 rows x 147 columns]

# %%
df.SALES.describe()
# Out:
# count     147.000000
# mean     3446.003537
# std      1717.988835
# min       652.350000
# 25%      2249.005000
# 50%      3160.740000
# 75%      4410.060000
# max      9774.030000
# Name: SALES, dtype: float64

# %%
df.SALES.mean()
# Out:
# 3446.0035374149647

# %%
df.SALES.value_counts()
# Out:
# 3965.66    1
# 5013.54    1
# 2848.86    1
# 2633.78    1
# 4042.08    1
#           ..
# 7956.46    1
# 4815.30    1
# 3528.36    1
# 5545.76    1
# 2189.60    1
# Name: SALES, Length: 147, dtype: int64

# %%
# %matplotlib inline

# %%
df.MSRP.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.MSRP.plot(kind = 'line')
# Out:
# <AxesSubplot:>
