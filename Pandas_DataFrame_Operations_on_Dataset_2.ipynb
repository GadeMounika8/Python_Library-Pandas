# %%
import pandas as pd
d2 = pd.read_csv(r"C:\\Users\\mouni\\Desktop\\whole folder\\Sales_Data.csv")
df11 = pd.DataFrame(d2)
df11
# Out:
#                                  Region              Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean               Panama      Snacks
# 2                                Europe       Czech Republic   Beverages
# 3                                  Asia          North Korea      Cereal
# 4                                  Asia            Sri Lanka      Snacks
# ...                                 ...                  ...         ...
# 4995              Australia and Oceania          New Zealand   Household
# 4996       Middle East and North Africa           Azerbaijan     Clothes
# 4997                               Asia              Myanmar   Baby Food
# 4998                             Europe              Finland     Clothes
# 4999                 Sub-Saharan Africa             Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11.head()
# Out:
#                               Region              Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1  Central America and the Caribbean               Panama     Snacks
# 2                             Europe       Czech Republic  Beverages
# 3                               Asia          North Korea     Cereal
# 4                               Asia            Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12-20-2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7-26-2010
# 2       Offline              C  09-12-2011  478051030.0   9-29-2011
# 3       Offline              L   5-13-2010  892599952.0   6-15-2010
# 4       Offline              C   7-20-2015  571902596.0   7-27-2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %%
df11.loc[3]
# Out:
# Region                      Asia
# Country              North Korea
# Item_Type                 Cereal
# Sales_Channel            Offline
# Order_Priority                 L
# Order_Date             5-13-2010
# Order_ID             892599952.0
# Ship_Date              6-15-2010
# Units_Sold                     0
# Unit_SellingPrice          205.7
# Unit_MakingCost           117.11
# Total_Revenue          1854591.2
# Total_Cost            1055863.76
# Total_Profit           798727.44
# Name: 3, dtype: object

# %%
df11.loc[3,"Item_Type"]
# Out:
# 'Cereal'

# %%
df11.loc[3,"Total_Profit"]
# Out:
# 798727.44

# %%
df11.loc[3,"Country"]
# Out:
# 'North Korea'

# %%
df11.loc[0]
# Out:
# Region               Central America and the Caribbean
# Country                            Antigua and Barbuda
# Item_Type                                    Baby Food
# Sales_Channel                                   Online
# Order_Priority                                       M
# Order_Date                                  12-20-2013
# Order_ID                                   957081544.0
# Ship_Date                                   01-11-2014
# Units_Sold                                           0
# Unit_SellingPrice                               255.28
# Unit_MakingCost                                 159.42
# Total_Revenue                                140914.56
# Total_Cost                                    87999.84
# Total_Profit                                  52914.72
# Name: 0, dtype: object

# %%
df11.loc[0:5,"Item_Type"]
# Out:
# 0        Baby Food
# 1           Snacks
# 2        Beverages
# 3           Cereal
# 4           Snacks
# 5    Personal Care
# Name: Item_Type, dtype: object

# %%
df11.loc[0:11,"Country"]
# Out:
# 0                Antigua and Barbuda
# 1                             Panama
# 2                     Czech Republic
# 3                        North Korea
# 4                          Sri Lanka
# 5                            Morocco
# 6     Federated States of Micronesia
# 7             Bosnia and Herzegovina
# 8                        Afghanistan
# 9                           Ethiopia
# 10                            Turkey
# 11                              Oman
# Name: Country, dtype: object

# %%
df11.loc[0:11,["Country","Total_Revenue"]]
# Out:
#                            Country  Total_Revenue
# 0              Antigua and Barbuda      140914.56
# 1                           Panama      330640.86
# 2                   Czech Republic      226716.10
# 3                      North Korea     1854591.20
# 4                        Sri Lanka     1150758.36
# 5                          Morocco        3923.04
# 6   Federated States of Micronesia      902434.24
# 7           Bosnia and Herzegovina      101302.56
# 8                      Afghanistan      966144.48
# 9                         Ethiopia     2506083.76
# 10                          Turkey     2412081.84
# 11                            Oman     3227410.40

# %%
df11.loc[0:11:2,["Country","Total_Revenue","Total_Profit"]]
# Out:
#                            Country  Total_Revenue  Total_Profit
# 0              Antigua and Barbuda      140914.56      52914.72
# 2                   Czech Republic      226716.10      74823.48
# 4                        Sri Lanka     1150758.36     415865.88
# 6   Federated States of Micronesia      902434.24     606467.52
# 8                      Afghanistan      966144.48     649283.04
# 10                          Turkey     2412081.84     467630.00

# %%
df11.loc[0:11:3,["Country","Total_Revenue","Total_Profit"]]df11.loc[0:20,["Country","Total_Revenue","Total_Profit"]].head()
# Out:
#                           Country  Total_Revenue  Total_Profit
# 0             Antigua and Barbuda      140914.56      52914.72
# 3                     North Korea     1854591.20     798727.44
# 6  Federated States of Micronesia      902434.24     606467.52
# 9                        Ethiopia     2506083.76     941057.62

# %%
df11.loc[0:20,["Country","Total_Revenue","Total_Profit"]]
# Out:
#                              Country  Total_Revenue  Total_Profit
# 0                Antigua and Barbuda      140914.56      52914.72
# 1                             Panama      330640.86     119488.38
# 2                     Czech Republic      226716.10      74823.48
# 3                        North Korea     1854591.20     798727.44
# 4                          Sri Lanka     1150758.36     415865.88
# 5                            Morocco        3923.04       1202.88
# 6     Federated States of Micronesia      902434.24     606467.52
# 7             Bosnia and Herzegovina      101302.56      68078.88
# 8                        Afghanistan      966144.48     649283.04
# 9                           Ethiopia     2506083.76     941057.62
# 10                            Turkey     2412081.84     467630.00
# 11                              Oman     3227410.40    1283508.34
# 12                          Malaysia     2008043.40     864815.58
# ...

# %%
df11.loc[0:20,["Country","Total_Revenue","Total_Profit"]].head()
# Out:
#                Country  Total_Revenue  Total_Profit
# 0  Antigua and Barbuda      140914.56      52914.72
# 1               Panama      330640.86     119488.38
# 2       Czech Republic      226716.10      74823.48
# 3          North Korea     1854591.20     798727.44
# 4            Sri Lanka     1150758.36     415865.88

# %%
df11.loc[0:5,"Country":"Order_Priority"]
# Out:
#                Country      Item_Type Sales_Channel Order_Priority
# 0  Antigua and Barbuda      Baby Food        Online              M
# 1               Panama         Snacks       Offline              C
# 2       Czech Republic      Beverages       Offline              C
# 3          North Korea         Cereal       Offline              L
# 4            Sri Lanka         Snacks       Offline              C
# 5              Morocco  Personal Care       Offline              L

# %%
df11.loc[0:5,"Country":"Total_Revenue"]
# Out:
#                Country      Item_Type Sales_Channel Order_Priority  \
# 0  Antigua and Barbuda      Baby Food        Online              M
# 1               Panama         Snacks       Offline              C
# 2       Czech Republic      Beverages       Offline              C
# 3          North Korea         Cereal       Offline              L
# 4            Sri Lanka         Snacks       Offline              C
# 5              Morocco  Personal Care       Offline              L
#
#    Order_Date     Order_ID   Ship_Date  Units_Sold  Unit_SellingPrice  \
# 0  12-20-2013  957081544.0  01-11-2014           0             255.28
# 1  07-05-2010  301644504.0   7-26-2010           0             152.58
# 2  09-12-2011  478051030.0   9-29-2011           0              47.45
# 3   5-13-2010  892599952.0   6-15-2010           0             205.70
# 4   7-20-2015  571902596.0   7-27-2015           0             152.58
# 5  11-08-2010  412882792.0  11-22-2010           0              81.73
#
# ...

# %%
df11.loc[0:5,"Country":"Total_Profit"]
# Out:
#                Country      Item_Type Sales_Channel Order_Priority  \
# 0  Antigua and Barbuda      Baby Food        Online              M
# 1               Panama         Snacks       Offline              C
# 2       Czech Republic      Beverages       Offline              C
# 3          North Korea         Cereal       Offline              L
# 4            Sri Lanka         Snacks       Offline              C
# 5              Morocco  Personal Care       Offline              L
#
#    Order_Date     Order_ID   Ship_Date  Units_Sold  Unit_SellingPrice  \
# 0  12-20-2013  957081544.0  01-11-2014           0             255.28
# 1  07-05-2010  301644504.0   7-26-2010           0             152.58
# 2  09-12-2011  478051030.0   9-29-2011           0              47.45
# 3   5-13-2010  892599952.0   6-15-2010           0             205.70
# 4   7-20-2015  571902596.0   7-27-2015           0             152.58
# 5  11-08-2010  412882792.0  11-22-2010           0              81.73
#
# ...

# %%
df11.loc["Country":"Total_Profit"]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item_Type, Sales_Channel, Order_Priority, Order_Date, Order_ID, Ship_Date, Units_Sold, Unit_SellingPrice, Unit_MakingCost, Total_Revenue, Total_Cost, Total_Profit]
# Index: []

# %%
df11["Total_Revenue"].head()
# Out:
# 0     140914.56
# 1     330640.86
# 2     226716.10
# 3    1854591.20
# 4    1150758.36
# Name: Total_Revenue, dtype: float64

# %%
df11.loc[0:5,"Total_Revenue"]
# Out:
# 0     140914.56
# 1     330640.86
# 2     226716.10
# 3    1854591.20
# 4    1150758.36
# 5       3923.04
# Name: Total_Revenue, dtype: float64

# %%
df11["Total_Revenue"].head(1)
# Out:
# 0    140914.56
# Name: Total_Revenue, dtype: float64

# %%
df11.loc[:0,"Total_Revenue"]
# Out:
# 0    140914.56
# Name: Total_Revenue, dtype: float64

# %%
df11.loc[1,"Total_Revenue"]
# Out:
# 330640.86

# %%
df11.iloc[0:6,1:11]
# Out:
#                Country      Item_Type Sales_Channel Order_Priority  \
# 0  Antigua and Barbuda      Baby Food        Online              M
# 1               Panama         Snacks       Offline              C
# 2       Czech Republic      Beverages       Offline              C
# 3          North Korea         Cereal       Offline              L
# 4            Sri Lanka         Snacks       Offline              C
# 5              Morocco  Personal Care       Offline              L
#
#    Order_Date     Order_ID   Ship_Date  Units_Sold  Unit_SellingPrice  \
# 0  12-20-2013  957081544.0  01-11-2014           0             255.28
# 1  07-05-2010  301644504.0   7-26-2010           0             152.58
# 2  09-12-2011  478051030.0   9-29-2011           0              47.45
# 3   5-13-2010  892599952.0   6-15-2010           0             205.70
# 4   7-20-2015  571902596.0   7-27-2015           0             152.58
# 5  11-08-2010  412882792.0  11-22-2010           0              81.73
#
# ...

# %%
df11.iloc[0:6,1:15]
# Out:
#                Country      Item_Type Sales_Channel Order_Priority  \
# 0  Antigua and Barbuda      Baby Food        Online              M
# 1               Panama         Snacks       Offline              C
# 2       Czech Republic      Beverages       Offline              C
# 3          North Korea         Cereal       Offline              L
# 4            Sri Lanka         Snacks       Offline              C
# 5              Morocco  Personal Care       Offline              L
#
#    Order_Date     Order_ID   Ship_Date  Units_Sold  Unit_SellingPrice  \
# 0  12-20-2013  957081544.0  01-11-2014           0             255.28
# 1  07-05-2010  301644504.0   7-26-2010           0             152.58
# 2  09-12-2011  478051030.0   9-29-2011           0              47.45
# 3   5-13-2010  892599952.0   6-15-2010           0             205.70
# 4   7-20-2015  571902596.0   7-27-2015           0             152.58
# 5  11-08-2010  412882792.0  11-22-2010           0              81.73
#
# ...

# %%
df11.iloc[0:6]
# Out:
#                               Region              Country      Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda      Baby Food
# 1  Central America and the Caribbean               Panama         Snacks
# 2                             Europe       Czech Republic      Beverages
# 3                               Asia          North Korea         Cereal
# 4                               Asia            Sri Lanka         Snacks
# 5       Middle East and North Africa              Morocco  Personal Care
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12-20-2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7-26-2010
# 2       Offline              C  09-12-2011  478051030.0   9-29-2011
# 3       Offline              L   5-13-2010  892599952.0   6-15-2010
# 4       Offline              C   7-20-2015  571902596.0   7-27-2015
# ...

# %%
df11[0:6]
# Out:
#                               Region              Country      Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda      Baby Food
# 1  Central America and the Caribbean               Panama         Snacks
# 2                             Europe       Czech Republic      Beverages
# 3                               Asia          North Korea         Cereal
# 4                               Asia            Sri Lanka         Snacks
# 5       Middle East and North Africa              Morocco  Personal Care
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12-20-2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7-26-2010
# 2       Offline              C  09-12-2011  478051030.0   9-29-2011
# 3       Offline              L   5-13-2010  892599952.0   6-15-2010
# 4       Offline              C   7-20-2015  571902596.0   7-27-2015
# ...

# %%
df11.head()
# Out:
#                               Region              Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1  Central America and the Caribbean               Panama     Snacks
# 2                             Europe       Czech Republic  Beverages
# 3                               Asia          North Korea     Cereal
# 4                               Asia            Sri Lanka     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12-20-2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7-26-2010
# 2       Offline              C  09-12-2011  478051030.0   9-29-2011
# 3       Offline              L   5-13-2010  892599952.0   6-15-2010
# 4       Offline              C   7-20-2015  571902596.0   7-27-2015
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# ...

# %%
df11.loc[0:5]
# Out:
#                               Region              Country      Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda      Baby Food
# 1  Central America and the Caribbean               Panama         Snacks
# 2                             Europe       Czech Republic      Beverages
# 3                               Asia          North Korea         Cereal
# 4                               Asia            Sri Lanka         Snacks
# 5       Middle East and North Africa              Morocco  Personal Care
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12-20-2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7-26-2010
# 2       Offline              C  09-12-2011  478051030.0   9-29-2011
# 3       Offline              L   5-13-2010  892599952.0   6-15-2010
# 4       Offline              C   7-20-2015  571902596.0   7-27-2015
# ...

# %%
df11.iloc[0:6,0]
# Out:
# 0    Central America and the Caribbean
# 1    Central America and the Caribbean
# 2                               Europe
# 3                                 Asia
# 4                                 Asia
# 5         Middle East and North Africa
# Name: Region, dtype: object

# %%
df11.iloc[0:6,3]
# Out:
# 0     Online
# 1    Offline
# 2    Offline
# 3    Offline
# 4    Offline
# 5    Offline
# Name: Sales_Channel, dtype: object

# %%
df11.iloc[0:6,1]
# Out:
# 0    Antigua and Barbuda
# 1                 Panama
# 2         Czech Republic
# 3            North Korea
# 4              Sri Lanka
# 5                Morocco
# Name: Country, dtype: object

# %%
df11.iloc[2,1:6]
# Out:
# Country           Czech Republic
# Item_Type              Beverages
# Sales_Channel            Offline
# Order_Priority                 C
# Order_Date            09-12-2011
# Name: 2, dtype: object

# %%
df11.iloc[0,0:]
# Out:
# Region               Central America and the Caribbean
# Country                            Antigua and Barbuda
# Item_Type                                    Baby Food
# Sales_Channel                                   Online
# Order_Priority                                       M
# Order_Date                                  12-20-2013
# Order_ID                                   957081544.0
# Ship_Date                                   01-11-2014
# Units_Sold                                           0
# Unit_SellingPrice                               255.28
# Unit_MakingCost                                 159.42
# Total_Revenue                                140914.56
# Total_Cost                                    87999.84
# Total_Profit                                  52914.72
# Name: 0, dtype: object

# %%
df11.iloc[0,1:]
# Out:
# Country              Antigua and Barbuda
# Item_Type                      Baby Food
# Sales_Channel                     Online
# Order_Priority                         M
# Order_Date                    12-20-2013
# Order_ID                     957081544.0
# Ship_Date                     01-11-2014
# Units_Sold                             0
# Unit_SellingPrice                 255.28
# Unit_MakingCost                   159.42
# Total_Revenue                  140914.56
# Total_Cost                      87999.84
# Total_Profit                    52914.72
# Name: 0, dtype: object

# %%
df11.iloc[3,:]
# Out:
# Region                      Asia
# Country              North Korea
# Item_Type                 Cereal
# Sales_Channel            Offline
# Order_Priority                 L
# Order_Date             5-13-2010
# Order_ID             892599952.0
# Ship_Date              6-15-2010
# Units_Sold                     0
# Unit_SellingPrice          205.7
# Unit_MakingCost           117.11
# Total_Revenue          1854591.2
# Total_Cost            1055863.76
# Total_Profit           798727.44
# Name: 3, dtype: object

# %%
df11.iloc[0:11,0:15]
# Out:
#                                Region                         Country  \
# 0   Central America and the Caribbean             Antigua and Barbuda
# 1   Central America and the Caribbean                          Panama
# 2                              Europe                  Czech Republic
# 3                                Asia                     North Korea
# 4                                Asia                       Sri Lanka
# 5        Middle East and North Africa                         Morocco
# 6               Australia and Oceania  Federated States of Micronesia
# 7                              Europe          Bosnia and Herzegovina
# 8        Middle East and North Africa                     Afghanistan
# 9                  Sub-Saharan Africa                        Ethiopia
# 10       Middle East and North Africa                          Turkey
#
#           Item_Type Sales_Channel Order_Priority  Order_Date     Order_ID  \
# ...

# %%
df11.iloc[[0,5]]
# Out:
#                               Region              Country      Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda      Baby Food
# 5       Middle East and North Africa              Morocco  Personal Care
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12-20-2013  957081544.0  01-11-2014
# 5       Offline              L  11-08-2010  412882792.0  11-22-2010
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# 0           0             255.28           159.42      140914.56    87999.84
# 5           0              81.73            56.67        3923.04     2720.16
#
#    Total_Profit
# 0      52914.72
# 5       1202.88

# %%
df11.iloc[[1,10]]
# Out:
#                                Region Country        Item_Type Sales_Channel  \
# 1   Central America and the Caribbean  Panama           Snacks       Offline
# 10       Middle East and North Africa  Turkey  Office Supplies       Offline
#
#    Order_Priority  Order_Date     Order_ID   Ship_Date  Units_Sold  \
# 1               C  07-05-2010  301644504.0   7-26-2010           0
# 10              C   9-25-2013  557156026.0  10-15-2013           0
#
#     Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# 1              152.58            97.44      330640.86   211152.48
# 10             651.21           524.96     2412081.84  1944451.84
#
#     Total_Profit
# 1      119488.38
# 10     467630.00

# %%
df11.iloc[[1,6,9,4,8]]
# Out:
#                               Region                         Country  \
# 1  Central America and the Caribbean                          Panama
# 6              Australia and Oceania  Federated States of Micronesia
# 9                 Sub-Saharan Africa                        Ethiopia
# 4                               Asia                       Sri Lanka
# 8       Middle East and North Africa                     Afghanistan
#
#    Item_Type Sales_Channel Order_Priority  Order_Date     Order_ID  \
# 1     Snacks       Offline              C  07-05-2010  301644504.0
# 6    Clothes       Offline              H   3-28-2011  932776868.0
# 9  Baby Food        Online              M   4-13-2015  192993152.0
# 4     Snacks       Offline              C   7-20-2015  571902596.0
# 8    Clothes       Offline              M   8-27-2016  579814469.0
#
#     Ship_Date  Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  \
# ...

# %%
df11.loc[[1,6,9,4,8]]
# Out:
#                               Region                         Country  \
# 1  Central America and the Caribbean                          Panama
# 6              Australia and Oceania  Federated States of Micronesia
# 9                 Sub-Saharan Africa                        Ethiopia
# 4                               Asia                       Sri Lanka
# 8       Middle East and North Africa                     Afghanistan
#
#    Item_Type Sales_Channel Order_Priority  Order_Date     Order_ID  \
# 1     Snacks       Offline              C  07-05-2010  301644504.0
# 6    Clothes       Offline              H   3-28-2011  932776868.0
# 9  Baby Food        Online              M   4-13-2015  192993152.0
# 4     Snacks       Offline              C   7-20-2015  571902596.0
# 8    Clothes       Offline              M   8-27-2016  579814469.0
#
#     Ship_Date  Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  \
# ...

# %%
df11.iloc[:,[0,5]]
# Out:
#                                  Region  Order_Date
# 0     Central America and the Caribbean  12-20-2013
# 1     Central America and the Caribbean  07-05-2010
# 2                                Europe  09-12-2011
# 3                                  Asia   5-13-2010
# 4                                  Asia   7-20-2015
# ...                                 ...         ...
# 4995              Australia and Oceania  04-03-2015
# 4996       Middle East and North Africa   8-17-2014
# 4997                               Asia  11-23-2016
# 4998                             Europe   4-22-2014
# 4999                 Sub-Saharan Africa  07-08-2011
#
# [5000 rows x 2 columns]

# %%
df11.iloc[:,[0,13]]
# Out:
#                                  Region  Total_Profit
# 0     Central America and the Caribbean      52914.72
# 1     Central America and the Caribbean     119488.38
# 2                                Europe      74823.48
# 3                                  Asia     798727.44
# 4                                  Asia     415865.88
# ...                                 ...           ...
# 4995              Australia and Oceania     879197.65
# 4996       Middle East and North Africa      79094.88
# 4997                               Asia     498855.44
# 4998                             Europe     691070.40
# 4999                 Sub-Saharan Africa     154668.50
#
# [5000 rows x 2 columns]

# %%
df11.iloc[:,[0,5,7,9,1,13]]
# Out:
#                                  Region  Order_Date   Ship_Date  \
# 0     Central America and the Caribbean  12-20-2013  01-11-2014
# 1     Central America and the Caribbean  07-05-2010   7-26-2010
# 2                                Europe  09-12-2011   9-29-2011
# 3                                  Asia   5-13-2010   6-15-2010
# 4                                  Asia   7-20-2015   7-27-2015
# ...                                 ...         ...         ...
# 4995              Australia and Oceania  04-03-2015   4-20-2015
# 4996       Middle East and North Africa   8-17-2014  10-02-2014
# 4997                               Asia  11-23-2016  12-10-2016
# 4998                             Europe   4-22-2014  05-11-2014
# 4999                 Sub-Saharan Africa  07-08-2011  08-07-2011
#
#       Unit_SellingPrice              Country  Total_Profit
# 0                255.28  Antigua and Barbuda      52914.72
# 1                152.58               Panama     119488.38
# ...

# %%
df11.iloc[:,:]
# Out:
#                                  Region              Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1     Central America and the Caribbean               Panama      Snacks
# 2                                Europe       Czech Republic   Beverages
# 3                                  Asia          North Korea      Cereal
# 4                                  Asia            Sri Lanka      Snacks
# ...                                 ...                  ...         ...
# 4995              Australia and Oceania          New Zealand   Household
# 4996       Middle East and North Africa           Azerbaijan     Clothes
# 4997                               Asia              Myanmar   Baby Food
# 4998                             Europe              Finland     Clothes
# 4999                 Sub-Saharan Africa             Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %% [markdown]
# # How to Perform Data cleaning?

# %% [markdown]
# 1. Data cleaning means fixing bad data in your data set.
#
# 2. Bad data could be:
#
# i. Empty cells
#
# ii. Data in wrong format
#
# iii. Wrong data
#
# iv. Duplicates

# %% [markdown]
# # What is Pandas - Cleaning Empty Cells?

# %% [markdown]
# 1. Empty cells can potentially give you a wrong result when you analyze data.
#
# 2. Remove rows
#
# 3. One way to deal with empty cells is to remove rows that contain empty cells.
#
# 4. This is usually ok, since data sets can be very big, and removing a few rows will not have a big impact on the result.
#
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.
#
# 5. If you want to change the original DataFrame, use the inplace = True argument.

# %% [markdown]
# # How to REPLACE Empty values?

# %% [markdown]
# Another way of dealing with empty cells is to insert a new value instead.
#
# This way you do not have to delete entire rows just because of some empty cells.
#
# The fillna() method allows us to replace empty cells with a value.

# %% [markdown]
# # How to Replace Empty values only for a specified columns?

# %% [markdown]
# To only replace empty values for one column, specify the column name for the Dataframe.

# %% [markdown]
# # How to fill empty values using MEAN, MEDIAN, or MODE?

# %% [markdown]
# 1.A common way to replace empty cells, is to calculate the mean, median, or mode values of the column.
#
# 2.Pandas uses the mean(),median() and mode() methods to calculate the representative values for a specified column:
#
# i. mean = The average value(the sum of all values divided by no: of values).
#
# ii. median = The value in the middle, after you have sorted all values ascending.
#
# iii. mode = The value that appears most frequently.

# %% [markdown]
# # How to Perform Pandas-cleaning Data of wrong Format?

# %% [markdown]
# 1.cells with data of wrong format can make it difficult , or even impossible, to analyze data.
#
# 2.To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

# %% [markdown]
# # What are the steps to convert into a corect format?

# %% [markdown]
# 1.Convert to Date
#
# 2.Correct format for date

# %% [markdown]
# # How to remove unwanted rows?

# %% [markdown]
# The result from the converting in the example above gave us a NaN value, which can be handled as a NULL value, and we can remove the row by using the dropna() method.

# %% [markdown]
# # How to fix wrong Data?

# %% [markdown]
# 1. "wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someone registerd "199" instead of "1.99".
#
# 2. Sometimes you can stop wrong data by looking at the data set, because you have an expectation of what it should be.

# %% [markdown]
# # What is Replacing values?

# %% [markdown]
# One way to fix wrong values is to replace them with something else.

# %% [markdown]
# # How to perform Replace values?

# %% [markdown]
# 1. Loop through all values in the "id" column.
#
# 2. If the value is higher than 300, set it to 500:

# %% [markdown]
# # How to Performing Rows?

# %% [markdown]
# 1. Another way of handling wrong data is to remove the rows that contains wrong data.
#
# 2. This way you do not have to find out what to replace them with, and there is a good chance you do not need them to do your analysis.

# %% [markdown]
# # What are Duplicates?

# %% [markdown]
# 1. Duplicates are rows that have been registered more than one time.
#
# 2. By taking a look at our test data set, we can assume that row 11 and 12 are duplicates.
#
# 3. To discover duplicates, we can use the duplicated() method.
#
# 4. The duplicated() method returns a Boolean values for each row:

# %% [markdown]
# # How to Remove Duplicates?

# %% [markdown]
# To remove duplicates, use the drop_duplicates() method.

# %% [markdown]
# # How to check pandas-Data correlation?

# %% [markdown]
# 1. A great aspect of the pandas module is the corr() method.
#
# 2. The corr() method calculates the relationship between each column in your data set.

# %% [markdown]
# # What is Pandas - Data correlation ?

# %% [markdown]
# --> The corr() method ignores "not numeric" columns.
#
# --> Result Explained the result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.
#
# --> The number varies from -1 to 1.
#
# --> 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set,each time a value went up in the first column,the other one went up as well.
#
# --> 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# --> -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# --> 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.
#
# --> What is a good correlation? it depends on the use, but i think it is safe to say you have to have at least 0.6(or -0.6) to call it a good correlation.
#
# --> Perfect correlation: We can see that "column1" and "column2" got the number 1.000000, which makes sense, each column always has a perfect relationship with itself.

# %%
df11.dropna()
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11.dropna(inplace=True)
df11
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11["Item_Type"].dropna()
# Out:
# 0       Baby Food
# 1          Snacks
# 2       Beverages
# 3          Cereal
# 4          Snacks
#           ...
# 4992      Clothes
# 4993      Clothes
# 4994    Cosmetics
# 4995    Household
# 4996      Clothes
# Name: Item_Type, Length: 4986, dtype: object

# %%
df11
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11["Units_Sold"].dropna(inplace=True)
df11
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11["Units_Sold"].fillna(30,inplace=True)
df11
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4992    False
# 4993    False
# 4994    False
# 4995    False
# 4996    False
# Length: 4986, dtype: bool

# %%
df11.drop_duplicates()
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df11.drop_duplicates(inplace = True)
df11
# Out:
#                                  Region              Country  Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda  Baby Food
# 1     Central America and the Caribbean               Panama     Snacks
# 2                                Europe       Czech Republic  Beverages
# 3                                  Asia          North Korea     Cereal
# 4                                  Asia            Sri Lanka     Snacks
# ...                                 ...                  ...        ...
# 4992       Middle East and North Africa                 Iran    Clothes
# 4993                             Europe              Denmark    Clothes
# 4994                 Sub-Saharan Africa              Liberia  Cosmetics
# 4995              Australia and Oceania          New Zealand  Household
# 4996       Middle East and North Africa           Azerbaijan    Clothes
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...
